# %% [markdown]
# # Table of Contents
#
# 1. [Gathering Data](#gda)
#
# 2. [Assessing Data](#ada)
#
#     2.1 [Observations](#ada1)
#
# 3. [Cleaning Data](#cda)
#
#     3.1 [Tidiness/Missing Values](#cda1)
#
#     3.2 [Quality Issues](#cda2)
#
#     3.3 [Merging all Three Dataframes](#cda3)
#
# 4. [Examining Final Dataframe](#eda)
#
# 5. [Analysis and Insights](#a&i)

# %%
#import statements

import tweepy
from tweepy import OAuthHandler
import numpy as np
import pandas as pd
import requests
import json
from timeit import default_timer as timer

# %% [markdown]
# # Gathering Data
#
# <a id="gda"></a>

# %% [markdown]
# ### Gathering Data from file directly from download
#
# <a id="gda1"></a>

# %%
#loading twitter-archive-enhanced.csv from download

df_csv = pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
# ### Gathering data programmitically from link provided
#
# <a id="gda2"></a>

# %%
#getting url from website provided by Udacity and using requests library to programatically load the file

url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
r = requests.get(url)

# %%
#writing contents of file provided from website as image-predictions.tsv

with open(url.split('/')[-1], mode='wb') as file:
    file.write(r.content)

# %%
df_tsv = pd.read_csv('image-predictions.tsv', sep='\t')

# %% [markdown]
# ### Gathering Data from Twitter API
#
# <a id="gda3"></a>

# %%
# consumer and access keys/tokens

consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

# %%
#authorization using consumer key/secret

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# %%
#authorization with access token/secret

auth.set_access_token(access_token, access_secret)

# %%
#setting API variable
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
#grabbing tweet_id values in df_csv dataframe and assigning that in the tweet_ids list

tweet_ids = df_csv.tweet_id.values

# %%
#code from twitter-api.py to access each tweet and append each line in a .txt file, this block will be commented 
#out due to the time it takes to run this block

count = 0
fails_dict = {}
start = timer()

#Save each tweet's returned JSON as a new line in a .txt file

with open('tweet_json.txt', 'w') as outfile:
    #This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %%
#creating empty tweets_list then running for loop to reach each line in json file then append it to list.  
#For each iteration, it starts with an empty dictionary, line_dict, then adds the values from each line that
#is loaded from the json file in terms of tweet_id, retweet_count, and favorite_count.
#This code is from the Knowledge forum from Myles C, which he used to help a student create the tweet_json.txt file

tweets_list = []
with open('tweet_json.txt') as file:
    for line in file:
        line_dict = {}
        json_line = json.loads(line)
        line_dict['tweet_id'] = json_line['id_str']
        line_dict['retweet_count'] = json_line['retweet_count']
        line_dict['favorite_count'] = json_line['favorite_count']
        tweets_list.append(line_dict)

# %%
df_twitter = pd.DataFrame(tweets_list)

# %% [markdown]
# # Assessing Data
#
# <a id="ada"></a>

# %%
#assessing df_csv

df_csv
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
df_csv.doggo.value_counts()
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64

# %%
df_csv[df_csv.expanded_urls.isnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# 179   857214891891077121           8.571567e+17         1.806710e+08
# 185   856330835276025856                    NaN                  NaN
# 186   856288084350160898           8.562860e+17         2.792810e+08
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 218   850333567704068097           8.503288e+17         2.195506e+07
# 228   848213670039564288           8.482121e+17         4.196984e+09
# 234   847617282490613760           8.476062e+17         4.196984e+09
# ...

# %%
df_csv.query('doggo == "doggo"')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 9     890240255349198849                    NaN                  NaN
# 43    884162670584377345                    NaN                  NaN
# 99    872967104147763200                    NaN                  NaN
# 108   871515927908634625                    NaN                  NaN
# 110   871102520638267392                    NaN                  NaN
# ...                  ...                    ...                  ...
# 1117  732375214819057664                    NaN                  NaN
# 1141  727644517743104000                    NaN                  NaN
# 1156  724771698126512129                    NaN                  NaN
# 1176  719991154352222208                    NaN                  NaN
# 1204  716080869887381504                    NaN                  NaN
#
#                       timestamp  \
# 9     2017-07-26 15:59:51 +0000
# 43    2017-07-09 21:29:42 +0000
# 99    2017-06-09 00:02:31 +0000
# ...

# %%
df_csv.floofer.value_counts()
# Out:
# None       2346
# floofer      10
# Name: floofer, dtype: int64

# %%
df_csv.query('floofer == "floofer"')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 46    883360690899218434                    NaN                  NaN
# 200   854010172552949760                    NaN                  NaN
# 582   800388270626521089                    NaN                  NaN
# 774   776218204058357768                    NaN                  NaN
# 984   749317047558017024                    NaN                  NaN
# 1022  746542875601690625                    NaN                  NaN
# 1091  737445876994609152                    NaN                  NaN
# 1110  733822306246479872                    NaN                  NaN
# 1534  689993469801164801                    NaN                  NaN
# 1614  685307451701334016                    NaN                  NaN
#
#                       timestamp  \
# 46    2017-07-07 16:22:55 +0000
# 200   2017-04-17 16:34:26 +0000
# 582   2016-11-20 17:20:08 +0000
# 774   2016-09-15 00:36:55 +0000
# 984   2016-07-02 19:01:20 +0000
# ...

# %%
#checking value counts of df_csv source column to see if it is something I can clean later

df_csv.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
#assessing df_tsv

df_tsv
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
df_tsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
#assessing df_twitter

df_twitter
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           7445           35271
# 1     892177421306343426           5531           30526
# 2     891815181378084864           3655           22958
# 3     891689557279858688           7610           38528
# 4     891327558926688256           8204           36810
# ...                  ...            ...             ...
# 2326  666049248165822465             39              95
# 2327  666044226329800704            123             262
# 2328  666033412701032449             39             108
# 2329  666029285002620928             41             118
# 2330  666020888022790149            445            2353
#
# [2331 rows x 3 columns]

# %%
df_twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2331 non-null   object
#  1   retweet_count   2331 non-null   int64
#  2   favorite_count  2331 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 54.8+ KB

# %% [markdown]
# ### Observations
#
# #### Quality Issues
#
# - Convert timestamp in df_csv column to date_time format
# - Convert tweet_id column in df_tsv to string values
# - Convert tweet_id column in df_csv to string values
# - Names in p1, p2, and p3 columns in df_tsv to be capitalized
# - Replace underscores with spaces in p1, p2, and p3 columns
# - Convert items in source column in df_csv dataframe from html tag to something more readable
# - Change rating numerator column to rating_out_of_10 column
# - Change classification column after it is created to categorical data type
#
# #### Tidiness Issues
#
# - Removing rows with retweets in text
#
# - Removing unnecessary columns from df_csv dataset (keeping tweet_id, source, timestamp, text, rating_out_of_10,
#     name, classification), which should fix the majority of the missing values
#
# - Combining doggo, pupper, and puppo into one column: classification
#
# - Merging dataframes to address uneven amount of user_id
#
# <a id="ada1"></a>

# %% [markdown]
# # Cleaning Data
#
# <a id="cda"></a>

# %%
#copying each dataframe to test cleaning process

df_csv_clean = df_csv.copy()
df_tsv_clean = df_tsv.copy()
df_twitter_clean = df_twitter.copy()

# %% [markdown]
# ### Define -- Tidiness Issues / Missing Values
#
# - Combine doggo, pupper, and pupo into one column, classification by adding a new column into df_csv dataframe: classification
#     Next create a for loop that goes through the doggo, pupper, and puppo columns and adds that value into the classification
#     column if it has the doggo, pupper or puppo name.  After the loop is done, then remove the preceding three columns.
# - Remove null values from retweet columns by using is_null() to remove rows containing retweets on the three retweet
#     columns
# - Remove unnecessary columns from df_csv_dataset by assigning the df_csv_clean dataframe the following columns:
#     keeping tweet_id, source, timestamp, text, rating_numerator, name, classification, and floofer
#
# <a id="cda1"></a>

# %% [markdown]
# ### Code -- Tidiness Issues / Missing Values

# %%
#adding classification column to dataframe by having it equal to the puppo column
df_csv_clean['classification'] = df_csv_clean['puppo']
df_csv_clean.sample()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1759  678740035362037760                    NaN                  NaN
#
#                       timestamp  \
# 1759  2015-12-21 00:53:29 +0000
#
#                                                  source  \
# 1759  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1759  Meet Tango. He's a large dog. Doesn't care muc...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1759                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1759  https://twitter.com/dog_rates/status/678740035...                 6
#
#       rating_denominator   name doggo floofer pupper puppo classification
# 1759                  10  Tango  None    None   None  None           None

# %%
# for loop to place values in doggo, pupper, puppo, and floofer columns into classification column if the respective columns 
# equal that value, else it will be null.  The counter is added if rows have multiple classifications

for x in range(df_csv_clean.shape[0]):
    temp_value = ""
    count = 0
    if df_csv_clean['doggo'][x] == 'doggo':
        temp_value = 'doggo'
        count += 1
    if df_csv_clean['puppo'][x] == 'puppo':
        temp_value = temp_value + ' puppo'
        count += 1
    if df_csv_clean['pupper'][x] == 'pupper':
        temp_value = temp_value + ' pupper'
        count +=1
    if df_csv_clean['floofer'][x] == 'floofer':
        temp_value = temp_value + ' floofer'
        count +=1
    if count == 0:
        df_csv_clean['classification'][x] = np.nan
    elif count == 1:
        temp_value = temp_value.strip()
        df_csv_clean['classification'][x] = temp_value
    else:
        temp_value = temp_value.strip()
        temp_value = temp_value.replace(' ', ', ')
        df_csv_clean['classification'][x] = temp_value
# Out:
# <ipython-input-77-5b06252a244d>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_csv_clean['classification'][x] = np.nan
# <ipython-input-77-5b06252a244d>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_csv_clean['classification'][x] = temp_value
# <ipython-input-77-5b06252a244d>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_csv_clean['classification'][x] = temp_value

# %%
#testing df_csv_classification column using value_counts() method to ensure classification column has the pupper,
#doggo, and puppo values

df_csv_clean.classification.value_counts()
# Out:
# pupper            245
# doggo              83
# puppo              29
# doggo, pupper      12
# floofer             9
# doggo, floofer      1
# doggo, puppo        1
# Name: classification, dtype: int64

# %%
#dropping the puppo, pupper, doggo, and floofer columns

df_csv_clean.drop('puppo', axis = 1, inplace = True)
df_csv_clean.drop('pupper', axis = 1, inplace = True)
df_csv_clean.drop('doggo', axis = 1, inplace = True)
df_csv_clean.drop('floofer', axis = 1, inplace = True)

# %%
#looking at columns list at remaining columns

df_csv_clean.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'classification'],
#       dtype='object')

# %%
#Remove null values from retweet columns by using is_null() to remove rows containing retweets on the three retweet columns
#Credit to the first person that checked my project and provided this code

df_csv_clean = df_csv_clean[df_csv_clean.retweeted_status_id.isnull()]
df_csv_clean = df_csv_clean[df_csv_clean.retweeted_status_user_id.isnull()]
df_csv_clean = df_csv_clean[df_csv_clean.retweeted_status_timestamp.isnull()]

# %%
#resetting index on df_csv_clean dataframe after removal of rows with retweets
df_csv_clean = df_csv_clean.reset_index(drop = True)

# %%
#Keeping tweet_id, timestamp, source, text, rating_numerator, name, and classification columns

df_csv_clean = df_csv_clean[['tweet_id', 'timestamp', 'source', 'text', 'rating_numerator', 'name', 'classification']]

# %% [markdown]
# ### Test -- Tidiness Issues / Missing Values

# %%
#testing resultant dataframe

df_csv_clean.sample()
# Out:
#                 tweet_id                  timestamp  \
# 1832  672245253877968896  2015-12-03 02:45:32 +0000
#
#                                                  source  \
# 1832  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  rating_numerator  \
# 1832  Meet Snickers. He's adorable. Also comes in t-...                12
#
#           name classification
# 1832  Snickers            NaN

# %% [markdown]
# ### Define -- Quality Issues
#
# - Convert timestamp in df_csv column to date_time format using pd.to_datetime()
# - Convert tweet_id column in df_tsv to string values using astype(str)
# - Convert tweet_id column in df_csv to string values using astype(str)
# - Names in p1, p2, and p3 columns in df_tsv to be more consistent naming using str.title() to capitalize all items especially
#     dog breeds
# - Replace underscores with spaces in p1, p2, and p3 columns by using str.replace()
# - Convert items in source column in df_csv dataframe from html tag to something more readable using str.split() and a for
#     loop to filter out the values in the html tags
# - Change rating numerator column to rating_out_of_10 column by using the rename method
# - Changing values in floofer column to 'Yes' or 'No' by running a for loop in that column and changing floofer to yes
#     and none to no
# - Change floofer column to categorical data type using astype()
# - Change classification column after it is created to categorical data type by using astype()
#
# <a id="cda2"></a>

# %% [markdown]
# ### Code -- Quality Issues
#
# #### Df_csv_clean

# %%
#converting timestamp in df_csv_clean column to date_time format using pd.to_datetime()

df_csv_clean.timestamp = pd.to_datetime(df_csv_clean.timestamp)

# %%
#converting tweet_id column in df_tsv_clean to string value

df_csv_clean.tweet_id = df_csv_clean.astype(str)

# %%
#Changing classification column in df_csv_clean column to category data type

df_csv_clean.classification = df_csv_clean.classification.astype('category')

# %%
df_csv_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2175 entries, 0 to 2174
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tweet_id          2175 non-null   object
#  1   timestamp         2175 non-null   datetime64[ns, UTC]
#  2   source            2175 non-null   object
#  3   text              2175 non-null   object
#  4   rating_numerator  2175 non-null   int64
#  5   name              2175 non-null   object
#  6   classification    344 non-null    category
# dtypes: category(1), datetime64[ns, UTC](1), int64(1), object(4)
# memory usage: 104.6+ KB

# %%
#convert values in df_csv_clean source column using str.split() and for loop

df_csv_clean.source = df_csv_clean.source.str.split(pat='>', n=1)

# %%
#for loop iterating through each value in source column and assigning it to the second half of the split string as well as
#trimming off the </a> tag

for x in range(df_csv_clean.shape[0]):
    df_csv_clean.source[x] = df_csv_clean.source[x][1][:-4]
# Out:
# <ipython-input-90-bd8559bfa258>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_csv_clean.source[x] = df_csv_clean.source[x][1][:-4]

# %%
#Changing rating_numerator column to rating_out_of_10 column using rename function

df_csv_clean.rename(columns = {'rating_numerator' : 'rating_out_of_10'}, inplace = True)

# %% [markdown]
# ### Test -- df_csv_clean dataframe

# %%
#sample of df_csv_clean dataset

df_csv_clean.sample(5)
# Out:
#                 tweet_id                 timestamp              source  \
# 1153  705475953783398401 2016-03-03 19:32:29+00:00  Twitter for iPhone
# 1598  677918531514703872 2015-12-18 18:29:07+00:00  Twitter for iPhone
# 406   813217897535406080 2016-12-26 03:00:30+00:00  Twitter for iPhone
# 274   833863086058651648 2017-02-21 02:17:06+00:00  Twitter for iPhone
# 879   742150209887731712 2016-06-13 00:22:53+00:00  Twitter for iPhone
#
#                                                    text  rating_out_of_10  \
# 1153  Say hello to Zara. She found a sandal and coul...                12
# 1598  "Everything looks pretty good in there. Make s...                10
# 406   Here is Atlas. He went all out this year. 13/1...                13
# 274   This is Bentley. Hairbrushes are his favorite ...                12
# 879   This is Edmund. He sends stellar selfies. Cute...                 8
#
#          name classification
# 1153     Zara            NaN
# 1598     None            NaN
# ...

# %%
df_csv_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2175 entries, 0 to 2174
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tweet_id          2175 non-null   object
#  1   timestamp         2175 non-null   datetime64[ns, UTC]
#  2   source            2175 non-null   object
#  3   text              2175 non-null   object
#  4   rating_out_of_10  2175 non-null   int64
#  5   name              2175 non-null   object
#  6   classification    344 non-null    category
# dtypes: category(1), datetime64[ns, UTC](1), int64(1), object(4)
# memory usage: 104.6+ KB

# %% [markdown]
# #### Df_tsv_clean

# %%
#converting tweet_id column in df_tsv_clean to string value

df_tsv_clean.tweet_id = df_tsv_clean.astype(str)

# %%
#Converting values in p1, p2, and p3 columns in df_tsv_clean to capital names using str.title()

df_tsv_clean.p1 = df_tsv_clean.p1.str.title()
df_tsv_clean.p2 = df_tsv_clean.p2.str.title()
df_tsv_clean.p3 = df_tsv_clean.p3.str.title()

# %%
#Replacing underscores with spaces in p1, p2, and p3 columns using str.replace()

df_tsv_clean.p1 = df_tsv_clean.p1.str.replace('_', ' ')
df_tsv_clean.p2 = df_tsv_clean.p2.str.replace('_', ' ')
df_tsv_clean.p3 = df_tsv_clean.p3.str.replace('_', ' ')

# %% [markdown]
# ### Test -- df_tsv_clean dataframe

# %%
#testing clean dataframe

df_tsv_clean.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 1272  750011400160841729  https://pbs.twimg.com/media/CmfmvGUWgAAuVKD.jpg
# 755   688385280030670848  https://pbs.twimg.com/media/CY2iwGNWUAI5zWi.jpg
# 685   683857920510050305  https://pbs.twimg.com/media/CX2NJmRWYAAxz_5.jpg
# 448   674690135443775488  https://pbs.twimg.com/media/CVz7FxXWUAAlTRP.jpg
# 632   680959110691590145  https://pbs.twimg.com/media/CXNAsm6WsAEST9R.jpg
# 1889  848324959059550208  https://pbs.twimg.com/media/C8XbDR1WAAAxND8.jpg
# 638   681281657291280384  https://pbs.twimg.com/media/CXRmDfWWMAADCdc.jpg
# 430   674269164442398721  https://pbs.twimg.com/media/CVt8OmIWIAAbxvJ.jpg
# 727   686377065986265092  https://pbs.twimg.com/media/CYaAS2kUoAINkye.jpg
# 1883  847251039262605312  https://pbs.twimg.com/media/C8IKUjAUwAEP-En.jpg
#
#       img_num                p1   p1_conf  p1_dog                  p2  \
# 1272        1            Muzzle  0.237620   False         Boston Bull
# ...

# %%
#testing conversion

df_tsv_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   object
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %% [markdown]
# ### Merging all three dataframes
#
# <a id="cda3"></a>

# %%
#Merging df_tsv_clean with df_twitter_clean

df_tsv_clean = df_tsv_clean.merge(df_twitter_clean, on = 'tweet_id')

# %%
#Showing merge result

df_tsv_clean
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2054  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2055  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2056  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2057  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2058  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
#Merging df_csv_clean with df_tsv_clean

df_csv_clean = df_csv_clean.merge(df_tsv_clean, on = 'tweet_id')

# %% [markdown]
# ## Examining Final Dataframe
#
# <a id="eda"></a>

# %%
#Looking at cleaned dataframe

df_csv_clean.head()
# Out:
#              tweet_id                 timestamp              source  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1  892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 2  891815181378084864 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 3  891689557279858688 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 4  891327558926688256 2017-07-29 16:00:24+00:00  Twitter for iPhone
#
#                                                 text  rating_out_of_10  \
# 0  This is Phineas. He's a mystical boy. Only eve...                13
# 1  This is Tilly. She's just checking pup on you....                13
# 2  This is Archie. He is a rare Norwegian Pouncin...                12
# 3  This is Darla. She commenced a snooze mid meal...                13
# 4  This is Franklin. He would like you to stop ca...                12
#
#        name classification                                          jpg_url  \
# ...

# %%
#checking datatypes of cleaned info

df_csv_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1987 entries, 0 to 1986
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tweet_id          1987 non-null   object
#  1   timestamp         1987 non-null   datetime64[ns, UTC]
#  2   source            1987 non-null   object
#  3   text              1987 non-null   object
#  4   rating_out_of_10  1987 non-null   int64
#  5   name              1987 non-null   object
#  6   classification    305 non-null    category
#  7   jpg_url           1987 non-null   object
#  8   img_num           1987 non-null   int64
#  9   p1                1987 non-null   object
#  10  p1_conf           1987 non-null   float64
#  11  p1_dog            1987 non-null   bool
#  12  p2                1987 non-null   object
#  13  p2_conf           1987 non-null   float64
#  14  p2_dog            1987 non-null   bool
#  15  p3                1987 non-null   object
# ...

# %% [markdown]
# #### Looking at the merged dataframe, it shows all quality and tidiness tasks have been completed.  The dataframe will be saved as twitter_archive_master and will be used in the analysis

# %%
#Saving Cleaned Dataframe as twitter_archive_master.csv

df_csv_clean.to_csv('twitter_archive_master.csv', index = False)

# %% [markdown]
# ## Analysis and Insights
#
# <a id="a&i"></a>

# %% [markdown]
# ### Insight 1: Does classification of dog associate with higher rating?

# %%
#creating df_insight_one dataframe filtering out rating_out_of_10 and classification

df_insight_one = df_csv_clean[['rating_out_of_10', 'classification']]

# %%
#removing null values from classification

df_insight_one = df_insight_one.dropna()

# %%
#grabbing sample of 5 after removing nulls

df_insight_one.sample(5)
# Out:
#      rating_out_of_10 classification
# 245                13          doggo
# 839                11          doggo
# 893                10         pupper
# 322                13          puppo
# 700                12         pupper

# %%
#setting up graph1 grouping by classification and sorting by the mean of the rating_out_of_10 values

graph1 = df_insight_one.groupby('classification')['rating_out_of_10'].mean().sort_values()
graph1
# Out:
# classification
# pupper            10.714286
# doggo, floofer    11.000000
# doggo, pupper     11.000000
# doggo             11.870968
# floofer           12.000000
# puppo             12.000000
# doggo, puppo      13.000000
# Name: rating_out_of_10, dtype: float64

# %%
#dropping rows that have multiple designations

graph1.drop('doggo, floofer', axis = 0, inplace = True)
graph1.drop('doggo, puppo', axis = 0, inplace = True)
graph1.drop('doggo, pupper', axis = 0, inplace = True)

# %%
#resultant graph1 after dropping

graph1
# Out:
# classification
# pupper     10.714286
# doggo      11.870968
# floofer    12.000000
# puppo      12.000000
# Name: rating_out_of_10, dtype: float64

# %%
#plotting a bar chart of graph1

graph1.plot(kind = 'bar',
            title = 'Classification of Dog Compared to Average Rating out of 10',
            ylabel = 'Mean Average Rating out of 10',
            xlabel = 'Classification of Dog',
            color = 'red');

# %% [markdown]
# ### Insight 2: Using the three prediction models, what percentage did each model pick a breed of dog?

# %%
#setting df_insight_two to p1_dog, p2_dog, and p3_dog showing if the prediction model actually picked a breed of dog
#or not

df_insight_two = df_csv_clean[['p1_dog', 'p2_dog', 'p3_dog']]

# %%
#looking at true values for p1_dog column

df_insight_two['p1_dog'].value_counts()
# Out:
# True     1470
# False     517
# Name: p1_dog, dtype: int64

# %%
#calculating percentage of true values vs total values for p1
print(1470/1987)
# Out:
# 0.7398087569199798

# %%
#Looking at true values for p2_dog column
df_insight_two['p2_dog'].value_counts()
# Out:
# True     1488
# False     499
# Name: p2_dog, dtype: int64

# %%
#calculating percentage of true values vs total values for p2
print(1488/1987)
# Out:
# 0.7488676396577756

# %%
#looking at true values for p3_dog column
df_insight_two['p3_dog'].value_counts()
# Out:
# True     1439
# False     548
# Name: p3_dog, dtype: int64

# %%
#calculating percentage of true values vs total values for p3
print(1439/1987)
# Out:
# 0.7242073477604429

# %% [markdown]
# ### Insight 3: What was the most popular tweet id out of the list in terms of favorite count and retweet count?

# %%
#setting up 3a dataframe sorting by retweet_count
df_insight_three_a = df_csv_clean.sort_values('retweet_count')

# %%
#using tail method to show the row with the highest retweet value
df_insight_three_a.tail(1)
# Out:
#                tweet_id                 timestamp              source  \
# 769  744234799360020481 2016-06-18 18:26:18+00:00  Twitter for iPhone
#
#                                                   text  rating_out_of_10  \
# 769  Here's a doggo realizing you can stand in a po...                13
#
#      name classification                                            jpg_url  \
# 769  None          doggo  https://pbs.twimg.com/ext_tw_video_thumb/74423...
#
#      img_num                  p1   p1_conf  p1_dog        p2   p2_conf  \
# 769        1  Labrador Retriever  0.825333    True  Ice Bear  0.044681
#
#      p2_dog       p3   p3_conf  p3_dog  retweet_count  favorite_count
# 769   False  Whippet  0.018442    True          75130          151946

# %%
#setting up 3b dataframe sorting by favorite count
df_insight_three_b = df_csv_clean.sort_values('favorite_count')

# %%
#using tail method to show the row with the highest favorite value
df_insight_three_b.tail(1)
# Out:
#                tweet_id                 timestamp              source  \
# 769  744234799360020481 2016-06-18 18:26:18+00:00  Twitter for iPhone
#
#                                                   text  rating_out_of_10  \
# 769  Here's a doggo realizing you can stand in a po...                13
#
#      name classification                                            jpg_url  \
# 769  None          doggo  https://pbs.twimg.com/ext_tw_video_thumb/74423...
#
#      img_num                  p1   p1_conf  p1_dog        p2   p2_conf  \
# 769        1  Labrador Retriever  0.825333    True  Ice Bear  0.044681
#
#      p2_dog       p3   p3_conf  p3_dog  retweet_count  favorite_count
# 769   False  Whippet  0.018442    True          75130          151946
